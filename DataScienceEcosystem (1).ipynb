# %% [markdown]
# # Data Science Tool and Ecosystem

# %% [markdown]
# ![2-title.jpg](attachment:7c78cf9f-99e3-4585-ba16-bb23fad98b2d.jpg)

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro.jpg](attachment:c0104f54-395a-447b-867f-fc411e847743.jpg)

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1. Python
# 2. R
# 3. SQL
# 4. ...and so on

# %% [markdown]
# ![4-dslanguages.jpg](attachment:b3660f36-efb7-4021-81e0-f4d2899f5840.jpg)

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:
# 1. ggplot
# 2. numpy
# 3. caret
# 4. ...so on

# %% [markdown]
# ### Data Science Tools:
# * jypternote
# * MySQL
# * Apache Airflow

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python:
# ### X + Y.
# ### (X + Y) - Z.
# ### X / Y

# %% [markdown]
# ### This a simple arithmetic expression to mutiply then add integers:

# %% [markdown]
# ![5-dslibraries.jpg](attachment:3ae89459-b9fd-4bd3-ace1-9e9c8601c0a2.jpg)

# %%
X = (3*4)+5
print(X)
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.jpg](attachment:bfb958ca-097c-4764-aebf-6ea0e92c0dba.jpg)

# %% [markdown]
# ### This will convert 200 minutes to hours by diving by 60:

# %%
Y = 200/60 
print(Y)
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.jpg](attachment:8a404def-621c-4ff4-bad8-e8fa73f0c7bb.jpg)

# %% [markdown]
# **Objectives:**
# * the popular languages that Data Scientists use
# * Some of the commonly used libraries
# * a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![10-objectives.jpg](attachment:2e085000-d603-4528-a12a-65eff092a70f.jpg)

# %% [markdown]
# ## Author: Yu Hong

# %% [markdown]
# ![11-authordetails.jpg](attachment:67927234-0a41-41b6-8e2f-74dace1bcf5b.jpg)

# %% [markdown]
# ![1-notebook.jpg](attachment:828ae40c-2e92-4e9b-b0ac-02a6b07c2ca3.jpg)
